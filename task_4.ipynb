# %%
hours=int(input("введите часы  "))
minutes=int(input("введите минуты  "))
seconds=int(input("введите секунды  "))
result=hours*3600+minutes*60+seconds
print('суммарное кол-во секунд равно ',result)
