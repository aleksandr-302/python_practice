# %%
a=float(input("введите длину комнаты "))
b=float(input("введите ширину комнаты "))
print('площадь равна',a*b)
# Out:
# введите длину комнаты 10.1
# введите ширину комнаты 10
# площадь равна 101.0
